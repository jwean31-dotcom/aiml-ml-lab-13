# %% [markdown]
# ## Name :- Jwean Dabre
# ## Roll No :- 13
# ## Batch :- 1
# ## ML Lab Exp 7

# %%
import time 
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
data = fetch_california_housing()
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
x = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

print(x.head())
print("Samples:",len(x))
print(y[:10])
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# Samples: 20640
# [4.526 3.585 3.521 3.413 3.422 2.697 2.992 2.414 2.267 2.611]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
tree = DecisionTreeRegressor()

start = time.perf_counter()
tree.fit(x_train,y_train)
tree_time= time.perf_counter() -start

pred_tree_test = tree.predict(x_test)
err_tree_test= mean_absolute_error(y_test,pred_tree_test)
pred_tree_train=tree.predict(x_train)
err_tree_train=mean_absolute_error(y_train,pred_tree_train)
print("Decision Tree Train MAE :" , err_tree_train)
print("Decision Tree Train MAE :" , err_tree_train)
print("Decision Tree Train time :" , tree_time)
# Out:
# Decision Tree Train MAE : 4.2655371052701026e-17
# Decision Tree Train MAE : 4.2655371052701026e-17
# Decision Tree Train time : 0.12455269999964003

# %%
rf = RandomForestRegressor()

start = time.perf_counter()
rf.fit(x_train,y_train)
rf_time= time.perf_counter() - start

pred_rf_test = rf.predict(x_test)
err_rf_test= mean_absolute_error(y_test,pred_rf_test)
pred_tree_train=rf.predict(x_train)
err_rf_train=mean_absolute_error(y_train,pred_rf_train)
print("Random Forest Train MAE :" , err_rf_train)
print("Random Forest Train MAE :" , err_rf_train)
print("Random Forest Train time :" , rf_time)
# Out:
# Random Forest Train MAE : 0.12162413527737441
# Random Forest Train MAE : 0.12162413527737441
# Random Forest Train time : 10.485285400000066

# %%
gb = GradientBoostingRegressor()

start = time.perf_counter()
gb.fit(x_train,y_train)
gb_time= time.perf_counter() - start

pred_gb_test = gb.predict(x_test)
err_gb_test= mean_absolute_error(y_test,pred_rf_test)
pred_gb_train=gb.predict(x_train)
err_gb_train=mean_absolute_error(y_train,pred_rf_train)
print("GradientBoosting :" , err_gb_train)
print("GradientBoosting :" , err_gb_train)
print("GradientBoosting :" , gb_time)
# Out:
# GradientBoosting : 0.12162413527737441
# GradientBoosting : 0.12162413527737441
# GradientBoosting : 3.3975977999998577

# %%
print("Decision Tree Train MAE :" , err_tree_train)
print("RandomForest :" , err_rf_train)
print("GradientBoosting :" , err_gb_train)

print("Decision Tree Train MAE :" , err_tree_train)
print("RandomForest :" , err_rf_train)
print("GradientBoosting :" , err_gb_train)

print("Decision Tree Train time :" , tree_time)
print("RandomForest:" , rf_time)
print("GradientBoosting:" , gb_time)
# Out:
# Decision Tree Train MAE : 4.2655371052701026e-17
# RandomForest : 0.12162413527737441
# GradientBoosting : 0.12162413527737441
# Decision Tree Train MAE : 4.2655371052701026e-17
# RandomForest : 0.12162413527737441
# GradientBoosting : 0.12162413527737441
# Decision Tree Train time : 0.12455269999964003
# RandomForest: 10.485285400000066
# GradientBoosting: 3.3975977999998577

# %%
print("\n===== Comparison For Test MAE =====")

print("Decision Tree Test :", err_tree_test)
print("Random Forest Test :", err_rf_test)
print("Gradient Boost Test:", err_gb_test)
# Out:
# ===== Comparison For Test MAE =====
# Decision Tree Test : 0.45501856831395354
# Random Forest Test : 0.32568341102228693
# Gradient Boost Test: 0.32568341102228693
